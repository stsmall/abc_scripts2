# %%
import seaborn as sns
import numpy as np
import pandas as pd
from math import log

# %%
df = pd.read_csv("examples/test.5000.sims.out.priors.out", header=[0,1], index_col=0, skipinitialspace=True)

# %%
log_low = log(100000, 10)
log_high = log(10, 10)

# %%
nn = np.random.randn(1000)
sns.displot(nn[nn>0])

# %%
sns.displot(np.random.exponential(8e-8, 100))
